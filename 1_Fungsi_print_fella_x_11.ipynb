# %% [markdown]
# <a href="https://colab.research.google.com/github/nisabuterflay/kka-x-semester-1/blob/main/1_Fungsi_print_fella_x_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama:fella najwa nisa
#
# Kelas:x.11
#
# No Absen:13

# %% [markdown]
# #menampilkan teks bebas

# %%
print("fella najwa nisa")
# Out:
# fella najwa nisa

# %% [markdown]
# #menampilkan nilai variabel

# %%
nama_saudara="idham kholit"

print(nama_saudara)
# Out:
# idham kholit

# %%
jumlah_saudara=3

print(jumlah_saudara)
# Out:
# 3

# %% [markdown]
# #menampilkan teks bebas dan nilai variabel

# %% [markdown]
# #menampilkan teks bebas dan nilai variabel menggunakan tanda koma

# %%
print("saya memiliki saudara sebanyak", jumlah_saudara, "nama saudara saya adalah", nama_saudara)
# Out:
# saya memiliki saudara sebanyak 3 nama saudara saya adalah idham kholit

# %% [markdown]
# #menampilkan teks bebas dan nilai variabel menggunakan tanda plus

# %%
print("saya memiliki saudara sebanyak "+str(jumlah_saudara)+". "+" nama saudara saya adalah "+nama_saudara+".")
# Out:
# saya memiliki saudara sebanyak 3.  nama saudara saya adalah idham kholit.

# %% [markdown]
# #Menampilkan Teks Bebas dan Nilai Variabel Menggunakan f String

# %%
print(f"saya memiliki saudara sebanyak {jumlah_saudara}. nama saudara saya adalah {nama_saudara}.")
# Out:
# saya memiliki saudara sebanyak 3. nama saudara saya adalah idham kholit.

# %% [markdown]
# #Escape Character

# %%
print("Nama: Fella Najwa")
print("Kelas: x.11")
print("No absen: 13")
# Out:
# Nama: Fella Najwa
# Kelas: x.11
# No absen: 13

# %%
print("Nama: Fella Najwa\nKelas: x.11\nNo absen: 13")
# Out:
# Nama: Fella Najwa
# Kelas: x.11
# No absen: 13

# %%
print("""Nama\t\t: Fella Najwa
Kelas\t\t: x.11
No absen\t: 13""")
# Out:
# Nama		: Fella Najwa
# Kelas		: x.11
# No absen	: 13

# %%
print("Fella Najwa")
# Out:
# Fella Najwa

# %%
print('Habib Ja\'far')
# Out:
# Habib Ja'far

# %%
print("Habib Ja'far")
# Out:
# Habib Ja'far

# %%
print('Bu Shinta berkata, "Harap fokus menyimak!".')
# Out:
# Bu Shinta berkata, "Harap fokus menyimak!".

# %%
print("Bu Shinta berkata, \"Harap fokus menyimak!\".")
# Out:
# Bu Shinta berkata, "Harap fokus menyimak!".

# %%
print("Lokasi penyimpanan tugas KKA di D:\\MAN Demak\\KKA\\Tugas")
# Out:
# Lokasi penyimpanan tugas KKA di D:\MAN Demak\KKA\Tugas

# %% [markdown]
# #Fungsi Parameter

# %%
nama_siswa_1="Daffanes"
nama_siswa_2="Adzka"
nama_siswa_3="Haidar"

print(nama_siswa_1)
print(nama_siswa_2)
print(nama_siswa_3)
# Out:
# Daffanes
# Adzka
# Haidar

# %%
print(nama_siswa_1, end=" ")
print(nama_siswa_2)
# Out:
# Daffanes Adzka

# %% [markdown]
# #Latihan soal:
# #Gunakan parameter end untuk menampilkan tulisan sebagai berikut:
# #Haidar#Adzka#Daffanes#Adzka

# %%
print(nama_siswa_3, end="-")
print(nama_siswa_2, end="-")
print(nama_siswa_1, end="-")
print(nama_siswa_2, )
# Out:
# Haidar-Adzka-Daffanes-Adzka
